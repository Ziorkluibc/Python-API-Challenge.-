# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests
import requests
import csv
import cartopy.crs as ccrs
import geoviews as gv # noqa
import pyproj
# Import API key
from api_keys import geoapify_key

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame

#Desktop/Module 6 Assignment/Starter_Code-12/output_data/cities.csv
city_data_df = pd.read_csv("output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0     trairi  -3.2778  -39.2689     25.32        94          62
# 1        1    ushuaia -54.8000  -68.3000      7.81        76          20
# 2        2  grytviken -54.2811  -36.5092      0.42        82          98
# 3        3     uturoa -16.7333 -151.4333     29.08        76          97
# 4        4   bengkulu  -3.8004  102.2655     28.56        80          95
#
#    Wind Speed Country        Date
# 0        1.54      BR  1712917019
# 1       12.35      AR  1712916845
# 2        4.70      GS  1712917057
# 3        8.97      PF  1712917057
# 4        2.40      ID  1712917057

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
humidity = city_data_df["Humidity"].astype(int)

city_map = city_data_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 700,
    frame_height = 500,
    size = "Humidity",
    alpha = 0.5,
    color = "city"
)
city_data_df.head()
# Display the map
city_map
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
ideal_weather1 = city_data_df.loc[city_data_df["Max Temp"] <78,]
Ideal_weather = ideal_weather1.loc[ideal_weather1["Max Temp"] > 68] 

city_wind = ideal_weather1.loc[ideal_weather1["Wind Speed"] > 4.0] 
city_Heat = ideal_weather1.loc[ideal_weather1["Humidity"] < 30]
city_cloud = ideal_weather1.loc[ideal_weather1["Cloudiness"] ==0] 
city_cloud

# Drop any rows with null values
ideal_city = city_cloud.dropna()

# Display sample data
ideal_city
# Out:
#      City_ID                      City      Lat       Lng  Max Temp  Humidity  \
# 24        24                   chonchi -42.6128  -73.8092      4.56        82
# 27        27                    medina  24.4686   39.6142     32.24        10
# 41        41              bagnacavallo  44.4125   11.9771     22.48        59
# 60        60  petropavlovsk-kamchatsky  53.0452  158.6483      1.33        93
# 70        70                     ancud -41.8697  -73.8203      7.72        76
# 74        74          port de pollenca  39.9075    3.0814     22.47        64
# 83        83                  cam ranh  11.9214  109.1591     28.98        84
# 89        89                     pisco -13.7000  -76.2167     22.03        83
# 90        90              longyearbyen  78.2186   15.6401    -13.09        52
# 113      113                    newman  37.3138 -121.0208     16.27        88
# 116      116                 taoudenni  22.6783   -3.9836     30.35        11
# ...

# %%
base_url =

# %%
#Step 3: Create a new DataFrame called `hotel_df`.
hotel_df = city_data_df.loc[:,["City", "Country", "Lat", "Lng", "Humidity"]]
hotel_df["Hotel Name"] = ""
hotel_df.head()
# Out:
#         City Country      Lat       Lng  Humidity Hotel Name
# 0     trairi      BR  -3.2778  -39.2689        94
# 1    ushuaia      AR -54.8000  -68.3000        76
# 2  grytviken      GS -54.2811  -36.5092        82
# 3     uturoa      PF -16.7333 -151.4333        76
# 4   bengkulu      ID  -3.8004  102.2655        80

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = ideal_city.loc[:,["City", "Country", "Lat", "Lng", "Humidity"]]

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df["Hotel Name"] = ""

# Display sample data
hotel_df.head()
# Out:
#                         City Country      Lat       Lng  Humidity Hotel Name
# 24                   chonchi      CL -42.6128  -73.8092        82
# 27                    medina      SA  24.4686   39.6142        10
# 41              bagnacavallo      IT  44.4125   11.9771        59
# 60  petropavlovsk-kamchatsky      RU  53.0452  158.6483        93
# 70                     ancud      CL -41.8697  -73.8203        76

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 70000
params = {
    "apikey" : geoapify_key, 
    "categories":"accomodation.hotel"
 }

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    lat = row["Lat"]
    lon = row["Lng"]
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{lon}, {lat}, {radius}"
    params["bias"] = f"proximity:{lon},{lat}"
    
    # Set base URL
    url = "https://api.geoapify.com/v2/places"
   
    # Make and API request using the params dictionaty
    name_address = requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
         hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["cities"]["name"]

    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# chonchi - nearest hotel: No hotel found
# medina - nearest hotel: No hotel found
# bagnacavallo - nearest hotel: No hotel found
# petropavlovsk-kamchatsky - nearest hotel: No hotel found
# ancud - nearest hotel: No hotel found
# port de pollenca - nearest hotel: No hotel found
# cam ranh - nearest hotel: No hotel found
# pisco - nearest hotel: No hotel found
# longyearbyen - nearest hotel: No hotel found
# newman - nearest hotel: No hotel found
# taoudenni - nearest hotel: No hotel found
# zouerate - nearest hotel: No hotel found
# huntsville - nearest hotel: No hotel found
# caldwell - nearest hotel: No hotel found
# haiku-pauwela - nearest hotel: No hotel found
# anadyr - nearest hotel: No hotel found
# fergus falls - nearest hotel: No hotel found
# neftcala - nearest hotel: No hotel found
# laguna - nearest hotel: No hotel found
# adrar - nearest hotel: No hotel found
# aleksandriyskaya - nearest hotel: No hotel found
# ...

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
hotel_map = hotel_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 700,
    frame_height = 600,
    size = "Humidity",
    alpha = 0.7,
    color = "blue",
    hover_cols = ["Hotel Name", "Country"]
)



# Display the map
hotel_map
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (Humidity,Hotel Name,Country)
